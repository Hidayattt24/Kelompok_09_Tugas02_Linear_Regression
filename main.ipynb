# %% [markdown]
# # 📌 Tugas 2 - Pembelajaran Mesin (Kelas A)
#
# ## 🎯 Deskripsi Tugas
# Tugas ini merupakan **Tugas 2** dalam mata kuliah **Pembelajaran Mesin Kelas A**. Setiap kelompok akan melakukan serangkaian analisis dan implementasi model regresi untuk memahami hubungan antara variabel dalam dataset e-commerce.
#
# ## 🛠️ Detail Project yang Harus Dikerjakan
#
# ### 1️⃣ Pemahaman Dataset
# - Menjelaskan **sumber data** dan **variabel yang digunakan**.
# - Menampilkan **statistik deskriptif** dan **visualisasi awal data**.
#
# ### 2️⃣ Eksplorasi Data dan Pra-pemrosesan
# - Menangani **missing values** *(jika ada)*.
# - Melakukan **normalisasi atau standarisasi** data *(jika diperlukan)*.
# - Menganalisis **korelasi antara variabel independen dan dependen**.
#
# ### 3️⃣ Implementasi Model
# - Membangun model **Linear Regression** dan **Polynomial Regression**.
# - Memilih **derajat polinomial** yang sesuai dengan dataset.
# - Menggunakan teknik validasi seperti **train-test split** atau **cross-validation**.
#
# ### 4️⃣ Evaluasi Model
# - Menggunakan **Mean Squared Error (MSE), R² Score, dan Mean Absolute Error (MAE)** sebagai metrik evaluasi.
# - Membandingkan **kinerja regresi linear dan polinomial**.
#
# ### 5️⃣ Analisis Hasil
# - Menginterpretasikan **koefisien regresi**.
# - Menyajikan **grafik regression line dan polynomial fit**.
# - Menyimpulkan apakah model yang dibuat **cukup baik dalam memprediksi target**.
#
# ### 6️⃣ Laporan dan Presentasi
# - **Laporan dalam format PDF** berisi seluruh hasil analisis dan implementasi.
# - **Slide presentasi** per kelompok untuk menjelaskan hasil analisis.
#
# ---
#
# 📌 **Selanjutnya:** Kita akan memulai dengan **Pemahaman Dataset**! 🚀

# %% [markdown]
# # 📊 Pemahaman Dataset
#
# ## 1️⃣ Pendahuluan
#
# Dataset yang digunakan dalam analisis ini adalah **eCommerce Product Dataset**. Dataset ini berisi informasi tentang produk yang dijual secara online, mencakup **harga, rating, jumlah ulasan, diskon, dan lainnya**.
#
# 📌 **Tujuan Penggunaan Dataset**
# Dataset ini akan digunakan untuk mengimplementasikan **Regresi Linear** dan **Regresi Polinomial** dalam analisis prediksi. Melalui eksperimen ini, kita akan mengeksplorasi hubungan antara fitur-fitur dalam dataset serta menganalisis pola tren yang dapat dioptimalkan untuk keperluan bisnis e-commerce.
#
# 📂 **Sumber Dataset**
# Dataset ini dapat diakses melalui tautan berikut:
# 🔗 [eCommerce Trends Dataset – Kaggle](https://www.kaggle.com/datasets/muhammadroshaanriaz/e-commerce-trends-a-guide-to-leveraging-dataset/code)
#
#
# ### 🔍 Variabel yang Digunakan:
# - **ProductID** : ID unik untuk setiap produk
# - **ProductName** : Nama produk
# - **Category** : Kategori produk
# - **Price** : Harga produk
# - **Rating** : Rating pelanggan terhadap produk
# - **NumReviews** : Jumlah ulasan produk
# - **StockQuantity** : Jumlah stok yang tersedia
# - **Discount** : Diskon dalam persentase
# - **Sales** : Jumlah produk terjual
# - **DateAdded** : Tanggal produk ditambahkan
# - **City** : Kota asal produk

# %% [markdown]
# ##  🔍 Menampilkan Data Awal
# Kode berikut membaca dataset dan menampilkan beberapa baris pertama:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
df = pd.read_csv('./data/ecommerce_product_dataset.csv')

print("First few rows of the dataset:")
print(df.head())
# Out:
# First few rows of the dataset:
#    ProductID ProductName     Category   Price  Rating  NumReviews  \
# 0          1  Headphones  Electronics  400.31     1.7        3772
# 1          2  Headphones  Electronics  235.03     2.3        2919
# 2          3  Smartwatch  Electronics  417.90     1.8        1184
# 3          4  Smartphone  Electronics  152.70     3.4        2047
# 4          5      Laptop  Electronics  394.74     1.8        1267
#
#    StockQuantity  Discount  Sales   DateAdded         City
# 0             20      0.08    466  2023-11-10  Albuquerque
# 1            663      0.33   1332  2023-09-28       Queens
# 2            459      0.31    252  2023-10-20       Austin
# 3            475      0.49   1806  2023-12-05       Dallas
# 4            831      0.23   1508  2023-08-10       Tucson

# %% [markdown]
# ##  🔍  Statistik Deskriptif
# Untuk memahami distribusi data numerik, kita melihat statistik deskriptif berikut:

# %%
# Statistik deskriptif untuk variabel numerik
print(df.describe())
# Out:
#          ProductID       Price       Rating   NumReviews  StockQuantity  \
# count  1000.000000  1000.00000  1000.000000  1000.000000    1000.000000
# mean    500.500000   253.77551     3.025600  2498.753000     495.395000
# std     288.819436   141.40362     1.151004  1463.241871     292.799253
# min       1.000000    10.11000     1.000000     3.000000       0.000000
# 25%     250.750000   133.09250     2.100000  1201.750000     241.750000
# 50%     500.500000   251.31000     3.100000  2476.000000     505.000000
# 75%     750.250000   375.82750     4.000000  3797.500000     743.500000
# max    1000.000000   499.74000     5.000000  4994.000000     993.000000
#
#           Discount        Sales
# count  1000.000000  1000.000000
# mean      0.251640  1011.037000
# std       0.146455   582.113466
# min       0.000000     0.000000
# 25%       0.130000   502.000000
# 50%       0.250000   998.000000
# 75%       0.380000  1540.000000
# max       0.500000  1997.000000

# %% [markdown]
# ##  🔍 Pengecekan Data
# Kode berikut untuk melihat jumlah nilai unik:

# %%
# Menampilkan jumlah nilai unik dalam dataset
print("\nJumlah Nilai Unik per Kolom:")
print(df.nunique())
# Out:
# Jumlah Nilai Unik per Kolom:
# ProductID        1000
# ProductName       100
# Category           25
# Price             990
# Rating             41
# NumReviews        908
# StockQuantity     629
# Discount           51
# Sales             766
# DateAdded         346
# City              101
# dtype: int64

# %% [markdown]
# ##  🔍 Mengecek Missing Values
# Kode berikut untuk Mengecek Missing Values pada dataset:

# %%
# Mengecek jumlah missing values
print("\nMissing Values dalam Dataset:")
print(df.isnull().sum())
# Out:
# Missing Values dalam Dataset:
# ProductID        0
# ProductName      0
# Category         0
# Price            0
# Rating           0
# NumReviews       0
# StockQuantity    0
# Discount         0
# Sales            0
# DateAdded        0
# City             0
# dtype: int64

# %% [markdown]
# ## Visualisasi Data 📊

# %%
import plotly.express as px

# %% [markdown]
# ### 📊 Histogram Harga Produk

# %%
# Histogram Harga Produk
fig_price = px.histogram(df, x="Price", nbins=30, title="Distribusi Harga Produk", marginal="box", opacity=0.7, color_discrete_sequence=["blue"])
fig_price.show()

# %% [markdown]
# ### 📊 Histogram Diskon

# %%
# Histogram Diskon
fig_discount = px.histogram(df, x="Discount", nbins=30, title="Distribusi Diskon", marginal="box", opacity=0.7, color_discrete_sequence=["green"])
fig_discount.show()

# %% [markdown]
# ### 📊 Histogram Rating Produk

# %%
# Histogram Rating Produk
fig_rating = px.histogram(df, x="Rating", nbins=30, title="Distribusi Rating Produk", marginal="box", opacity=0.7, color_discrete_sequence=["orange"])
fig_rating.show()

# %% [markdown]
# ### 📊 Histogram Jumlah Ulasan

# %%
# Histogram Jumlah Ulasan
fig_reviews = px.histogram(df, x="NumReviews", nbins=30, title="Distribusi Jumlah Ulasan", marginal="box", opacity=0.7, color_discrete_sequence=["purple"])
fig_reviews.show()

# %% [markdown]
# ### 📊 Histogram Pendapatan (Sales)

# %%
# Histogram Pendapatan (Sales)
fig_sales = px.histogram(df, x="Sales", nbins=30, title="Distribusi Pendapatan (Sales)", marginal="box", opacity=0.7, color_discrete_sequence=["red"])
fig_sales.show()

# %% [markdown]
# ### 📊 Scatter Plot Harga, Diskon, Rating, Jumlah Ulasan vs Sales

# %%
# Scatter Plot antara Harga, Diskon, Rating, Jumlah Ulasan vs Sales
sns.pairplot(df[['Sales', 'Price', 'Discount', 'Rating', 'NumReviews']], diag_kind="kde")
plt.show()

# %% [markdown]
# ### 📊 Matriks Kolerasi

# %%
# Korelasi antar variabel
plt.figure(figsize=(8, 6))
sns.heatmap(df[['Sales', 'Price', 'Discount', 'Rating', 'NumReviews']].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Matriks Korelasi Variabel")
plt.show()

# %% [markdown]
# ### 🔗 Analisis Kategori Produk

# %%
if "Category" in df.columns:
    # Menampilkan kategori unik dan jumlah kategori
    unique_categories = df["Category"].unique()
    num_categories = df["Category"].nunique()
    
    print("Kategori Produk Unik:", unique_categories)
    print("Jumlah Kategori Produk:", num_categories)

    # Hitung jumlah tiap kategori
    category_counts = df["Category"].value_counts().reset_index()
    category_counts.columns = ["Category", "count"]  # Pastikan kolom memiliki nama yang sesuai

    # Bar Chart untuk distribusi kategori produk
    fig_bar = px.bar(
        category_counts,
        x="Category",
        y="count",
        title="Distribusi Kategori Produk",
        labels={"Category": "Kategori Produk", "count": "Jumlah"},
        color="Category",
        color_discrete_sequence=px.colors.qualitative.Vivid
    )
    fig_bar.update_xaxes(tickangle=45)
    fig_bar.show()

    # Pie Chart untuk distribusi kategori produk
    fig_pie = px.pie(
        category_counts,
        names="Category",
        values="count",
        title="Proporsi Kategori Produk",
        color_discrete_sequence=px.colors.qualitative.Pastel
    )
    fig_pie.show()
# Out:
# Kategori Produk Unik: ['Electronics' 'Clothing' 'Home & Kitchen' 'Books' 'Toys & Games'
#  'Vitamins and supplements' 'Skin care' 'Makeup' 'Coats and jackets'
#  'Bicycles' 'Art and crafting materials' 'Drinkware' 'Perfume and cologne'
#  'Wine' 'Socks' 'Bedsheets' 'Posters and artwork' 'Candles'
#  'Bath and body' 'Cookware' 'Nail care' 'Underwear' 'Motor vehicle parts'
#  'Mobile phone accessories' 'Blankets']
# Jumlah Kategori Produk: 25

# %% [markdown]
# # 🛠️ Eksplorasi Data dan Pra-pemrosesan

# %% [markdown]
# ## 🛠️ **Pilih Kolom yang Relevan untuk Analisis**
# Karena kita hanya tertarik pada target (Sales) dan fitur yang mempengaruhinya (Price, Discount, Rating, NumReviews), kita buat dataset baru yang hanya berisi kolom-kolom tersebut:

# %%
# Pilih hanya kolom yang relevan untuk analisis
selected_columns = ["Sales", "Price", "Discount", "Rating", "NumReviews"]
df_clean = df[selected_columns]  # Menggunakan raw_data sebagai dataset awal

# Tampilkan 5 data pertama untuk verifikasi
print(df_clean.head())
# Out:
#    Sales   Price  Discount  Rating  NumReviews
# 0    466  400.31      0.08     1.7        3772
# 1   1332  235.03      0.33     2.3        2919
# 2    252  417.90      0.31     1.8        1184
# 3   1806  152.70      0.49     3.4        2047
# 4   1508  394.74      0.23     1.8        1267

# %% [markdown]
# ✅ Penjelasan:
#
# Hanya kolom yang sesuai dengan fitur yang ditentukan dalam soal yang digunakan (Sales, Price, Discount, Rating, dan NumReviews).
#
# Data ini akan digunakan untuk eksplorasi lebih lanjut.

# %% [markdown]
# ## 🛠️ **Menangani Missing Values (Jika Ada)**
# Sebelum membangun model machine learning, penting untuk memastikan bahwa dataset tidak memiliki **missing values** (nilai yang hilang). Missing values dapat menyebabkan bias dalam analisis dan memengaruhi performa model prediktif.
#
# Untuk menangani missing values, kita dapat melakukan langkah-langkah berikut:
# 1. **Menampilkan jumlah missing values di setiap kolom**
# 2. **Menghapus atau mengisi nilai yang hilang berdasarkan strategi yang sesuai**
#    - Menghapus baris/kolom dengan terlalu banyak missing values
#    - Mengisi nilai yang hilang dengan **mean/median** (untuk numerik) atau **modus** (untuk kategorikal)
#
# Berikut adalah kode untuk mengecek dan menangani missing values:

# %%
# Cek missing values dalam dataset
missing_values = df_clean.isnull().sum()
print("Missing values per kolom:\n", missing_values)
# Out:
# Missing values per kolom:
#  Sales         0
# Price         0
# Discount      0
# Rating        0
# NumReviews    0
# dtype: int64

# %% [markdown]
# ✅ Penjelasan:
#
# Tidak ada nilai missing di setiap kolom.
#
# Jika ada nilai kosong, perlu dilakukan imputasi atau penghapusan data.

# %% [markdown]
# ## 🛠️ **Menangani Outlier**
# Sebelum menghapus atau menangani outlier, kita perlu mengidentifikasi outlier menggunakan Interquartile Range (IQR):

# %%
# Menghitung IQR
Q1 = df_clean.quantile(0.25)
Q3 = df_clean.quantile(0.75)
IQR = Q3 - Q1

# Menentukan batas bawah dan atas
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Menandai outlier
outliers = ((df_clean < lower_bound) | (df_clean > upper_bound))

# Menampilkan jumlah outlier per kolom
print("Jumlah outlier per kolom:\n", outliers.sum())
# Out:
# Jumlah outlier per kolom:
#  Sales         0
# Price         0
# Discount      0
# Rating        0
# NumReviews    0
# dtype: int64

# %% [markdown]
# ✅ Penjelasan:
#
# IQR digunakan untuk menentukan nilai yang dianggap outlier (di luar rentang normal).
#
# Tidak ada outlier yang terdeteksi pada data ini.

# %% [markdown]
# ## 🛠️**Visualisasi Outlier dengan Boxplot**
# Setelah mendeteksi outlier, kita bisa melihat distribusi datanya dengan boxplot:

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_clean)
plt.title("Boxplot untuk Deteksi Outlier")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ✅ Penjelasan:
#
# Boxplot menunjukkan distribusi data untuk setiap kolom.
#
# Tidak ada titik ekstrem yang muncul di luar whiskers, menandakan tidak adanya outlier.

# %% [markdown]
# ## 🛠️**Menghitung Persentase Outlier dengan IQR**
# Untuk memahami dampak outlier dalam dataset:

# %%
# Menghitung persentase outlier per kolom
outlier_percentage = (outliers.sum() / len(df_clean)) * 100
print("Persentase outlier per kolom:\n", outlier_percentage)
# Out:
# Persentase outlier per kolom:
#  Sales         0.0
# Price         0.0
# Discount      0.0
# Rating        0.0
# NumReviews    0.0
# dtype: float64

# %% [markdown]
# ✅ Penjelasan:
#
# Persentase outlier di semua kolom adalah 0%, artinya semua data dalam rentang normal.
#
# Jika ada outlier, bisa dilakukan penanganan seperti transformasi atau penghapusan data ekstrem.

# %% [markdown]
# ## 🛠️**Normalisasi atau Standarisasi Data (Jika Diperlukan)**
# ✅ Kenapa dibutuhkan?
#
# Normalisasi atau standarisasi diperlukan jika skala antar fitur sangat berbeda.
#
# Contoh: Sales memiliki nilai ribuan, sementara Discount hanya dalam rentang 0-1.
#
# 📌 Kode (Standarisasi dengan StandardScaler)

# %%
from sklearn.preprocessing import StandardScaler

# Standarisasi hanya untuk kolom numerik kecuali target (Sales)
scaler = StandardScaler()
df_clean_scaled = df_clean.copy()
df_clean_scaled[["Price", "Discount", "Rating", "NumReviews"]] = scaler.fit_transform(df_clean[["Price", "Discount", "Rating", "NumReviews"]])

# Tampilkan data setelah standarisasi
print(df_clean_scaled.head())
# Out:
#    Sales     Price  Discount    Rating  NumReviews
# 0    466  1.036804 -1.172553 -1.152267    0.870590
# 1   1332 -0.132634  0.535314 -0.630722    0.287346
# 2    252  1.161262  0.398685 -1.065343   -0.898970
# 3   1806 -0.715159  1.628349  0.325444   -0.308889
# 4   1508  0.997393 -0.147833 -1.065343   -0.842218

# %% [markdown]
# 📌 Penjelasan:
#
# Kolom Price, Discount, Rating, dan NumReviews telah distandarisasi (rata-rata 0, standar deviasi 1).
#
# Sales tidak distandarisasi karena merupakan target prediksi.

# %% [markdown]
# ## 🛠️**Encoding Data Kategorik**
# ✅ Apakah diperlukan?
#
# Tidak perlu, karena semua kolom sudah berbentuk numerik.

# %% [markdown]
# ## 🛠️**Membuat Heatmap Korelasi**
# ✅ Kenapa dibutuhkan?
#
# Heatmap korelasi membantu melihat hubungan antar variabel.
#
# Korelasi tinggi menunjukkan keterkaitan kuat antara fitur dan target (Sales).
#
# 📌 Kode (Heatmap Korelasi)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Hitung matriks korelasi
correlation_matrix = df_clean.corr()

# Visualisasi dengan heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Heatmap Korelasi")
plt.show()

# %% [markdown]
# 📌 Penjelasan dari Gambar Heatmap:
#
# - Semua variabel memiliki korelasi sempurna (1.00) dengan dirinya sendiri, yang memang merupakan hal yang normal.
# - Korelasi antara Sales dengan variabel lain sangat lemah: 0.03 dengan Price, 0.03 dengan Discount, 0.01 dengan Rating, dan 0.06 dengan NumReviews.
# - Price memiliki korelasi negatif sangat lemah dengan Discount (-0.05) dan Rating (-0.01).
# - Discount memiliki korelasi sangat lemah dengan Rating (0.02) dan korelasi negatif sangat lemah dengan NumReviews (-0.02).
# - Rating memiliki korelasi negatif sangat lemah dengan NumReviews (-0.01).

# %% [markdown]
# ## 🎯 **Kesimpulan Akhir**
# - Dataset tidak memiliki missing values dan outlier, menunjukkan kualitas data yang baik dan konsisten.
# - Variabel-variabel dalam dataset memiliki skala yang sangat berbeda, dengan NumReviews memiliki rentang nilai terbesar dan Discount memiliki rentang nilai terkecil. Standarisasi data telah dilakukan untuk menyamakan skala variabel.
# - Tidak ada korelasi yang signifikan antara variabel-variabel dalam dataset, dengan semua nilai korelasi kurang dari 0.1 (nilai absolut). Ini mengindikasikan bahwa variabel-variabel tersebut bergerak secara independen satu sama lain.
# - Sales, yang mungkin merupakan variabel target, hampir tidak memiliki hubungan linear dengan variabel prediktor lainnya. Korelasi tertinggi adalah dengan NumReviews (0.06), namun masih sangat lemah.
# - Jika tujuan analisis adalah untuk memprediksi Sales berdasarkan variabel lain, model linear mungkin tidak akan memberikan hasil yang memuaskan karena lemahnya korelasi. Pendekatan non-linear atau penambahan variabel prediktor lain mungkin perlu dipertimbangkan.
# - Meskipun korelasi antara variabel lemah, visualisasi boxplot menunjukkan bahwa dataset memiliki variasi yang cukup dalam distribusi nilai, yang mungkin mengandung pola-pola tersembunyi yang tidak terdeteksi oleh analisis korelasi sederhana.
